# %% [markdown]
# # Masterarbeit Jupyter Notebook
#
# Dies ist ein Beispiel-Notebook für Ihre Masterarbeit.

# %%
# Beispiel für Python-Code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Beispieldaten
data = np.random.randn(100)
plt.figure(figsize=(10, 6))
plt.hist(data, bins=20)
plt.title('Beispiel-Histogramm')
plt.show()

# %% [markdown]
# ## Notizen
#
# Hier können Sie Ihre Analysen und Ergebnisse für Ihre Masterarbeit dokumentieren.
